# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
#Importing weather data (Files have to be in same folder as the code file)
Path_2015 = os.getcwd() + '/New York City-March - May 2015.csv'
Path_2016 = os.getcwd() + '/New York City-March - May 2016.csv'
Path_2017 = os.getcwd() + '/New York City-March - May 2017.csv'
Path_2018 = os.getcwd() + '/New York City-March - May 2018.csv'

#Convert csv files to dataframe
Weather_2015 = pd.read_csv(Path_2015)
Weather_2016 = pd.read_csv(Path_2016)
Weather_2017 = pd.read_csv(Path_2017)
Weather_2018 = pd.read_csv(Path_2018)

#Combine dataframes
Weather = pd.concat([Weather_2015, Weather_2016, Weather_2017, Weather_2018],ignore_index=True)
Weather.shape
Weather
# Out:
#               name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0    New York City  2015-03-01     -1.2     -4.5  -2.9          -2.2
# 1    New York City  2015-03-02      3.4     -2.1   0.5          -0.5
# 2    New York City  2015-03-03      2.0     -5.0  -1.8          -1.5
# 3    New York City  2015-03-04      7.2      2.0   4.5           5.8
# 4    New York City  2015-03-05      4.6     -6.4  -2.6           1.7
# ..             ...         ...      ...      ...   ...           ...
# 363  New York City  2018-05-27     26.7     13.9  18.2          26.7
# 364  New York City  2018-05-28     20.6     13.4  16.1          20.6
# 365  New York City  2018-05-29     30.8     17.0  23.7          30.9
# 366  New York City  2018-05-30     23.8     16.1  19.9          23.8
# 367  New York City  2018-05-31     20.0     17.2  18.5          20.0
#
#      feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# ...

# %%
#Importing taxi data (Files have to be in same folder as the code file)
Path_March_2015 = os.getcwd() + '/yellow_tripdata_2015-03.parquet'
Path_April_2015 = os.getcwd() + '/yellow_tripdata_2015-04.parquet'
Path_May_2015 = os.getcwd() + '/yellow_tripdata_2015-05.parquet'
Path_March_2016 = os.getcwd() + '/yellow_tripdata_2016-03.parquet'
Path_April_2016 = os.getcwd() + '/yellow_tripdata_2016-04.parquet'
Path_May_2016 = os.getcwd() + '/yellow_tripdata_2016-05.parquet'
Path_March_2017 = os.getcwd() + '/yellow_tripdata_2017-03.parquet'
Path_April_2017 = os.getcwd() + '/yellow_tripdata_2017-04.parquet'
Path_May_2017 = os.getcwd() + '/yellow_tripdata_2017-05.parquet'
Path_March_2018 = os.getcwd() + '/yellow_tripdata_2018-03.parquet'
Path_April_2018 = os.getcwd() + '/yellow_tripdata_2018-04.parquet'
Path_May_2018 = os.getcwd() + '/yellow_tripdata_2018-05.parquet'

#Convert csv files to dataframe
#Split the datetime column into separate date and time columns
#Remove all pickup dates outtside of the month of interest (there is a lot of incorrect data)
Taxi_March_2015 = pd.read_parquet(Path_March_2015)
Taxi_March_2015['Date'] = pd.to_datetime(Taxi_March_2015['tpep_pickup_datetime']).dt.date
Taxi_March_2015['Time'] = pd.to_datetime(Taxi_March_2015['tpep_pickup_datetime']).dt.time
Taxi_March_2015 = Taxi_March_2015[pd.to_datetime(Taxi_March_2015['Date']).dt.month == 3]
Taxi_March_2015 = Taxi_March_2015[pd.to_datetime(Taxi_March_2015['Date']).dt.year == 2015]

Taxi_April_2015 = pd.read_parquet(Path_April_2015)
Taxi_April_2015['Date'] = pd.to_datetime(Taxi_April_2015['tpep_pickup_datetime']).dt.date
Taxi_April_2015['Time'] = pd.to_datetime(Taxi_April_2015['tpep_pickup_datetime']).dt.time
Taxi_April_2015 = Taxi_April_2015[pd.to_datetime(Taxi_April_2015['Date']).dt.month == 4]
Taxi_April_2015 = Taxi_April_2015[pd.to_datetime(Taxi_April_2015['Date']).dt.year == 2015]

Taxi_May_2015 = pd.read_parquet(Path_May_2015)
Taxi_May_2015['Date'] = pd.to_datetime(Taxi_May_2015['tpep_pickup_datetime']).dt.date
Taxi_May_2015['Time'] = pd.to_datetime(Taxi_May_2015['tpep_pickup_datetime']).dt.time
Taxi_May_2015 = Taxi_May_2015[pd.to_datetime(Taxi_May_2015['Date']).dt.month == 5]
Taxi_May_2015 = Taxi_May_2015[pd.to_datetime(Taxi_May_2015['Date']).dt.year == 2015]

Taxi_March_2016 = pd.read_parquet(Path_March_2016)
Taxi_March_2016['Date'] = pd.to_datetime(Taxi_March_2016['tpep_pickup_datetime']).dt.date
Taxi_March_2016['Time'] = pd.to_datetime(Taxi_March_2016['tpep_pickup_datetime']).dt.time
Taxi_March_2016 = Taxi_March_2016[pd.to_datetime(Taxi_March_2016['Date']).dt.month == 3]
Taxi_March_2016 = Taxi_March_2016[pd.to_datetime(Taxi_March_2016['Date']).dt.year == 2016]

Taxi_April_2016 = pd.read_parquet(Path_April_2016)
Taxi_April_2016['Date'] = pd.to_datetime(Taxi_April_2016['tpep_pickup_datetime']).dt.date
Taxi_April_2016['Time'] = pd.to_datetime(Taxi_April_2016['tpep_pickup_datetime']).dt.time
Taxi_April_2016 = Taxi_April_2016[pd.to_datetime(Taxi_April_2016['Date']).dt.month == 4]
Taxi_April_2016 = Taxi_April_2016[pd.to_datetime(Taxi_April_2016['Date']).dt.year == 2016]

Taxi_May_2016 = pd.read_parquet(Path_May_2016)
Taxi_May_2016['Date'] = pd.to_datetime(Taxi_May_2016['tpep_pickup_datetime']).dt.date
Taxi_May_2016['Time'] = pd.to_datetime(Taxi_May_2016['tpep_pickup_datetime']).dt.time
Taxi_May_2016 = Taxi_May_2016[pd.to_datetime(Taxi_May_2016['Date']).dt.month == 5]
Taxi_May_2016 = Taxi_May_2016[pd.to_datetime(Taxi_May_2016['Date']).dt.year == 2016]

Taxi_March_2017 = pd.read_parquet(Path_March_2017)
Taxi_March_2017['Date'] = pd.to_datetime(Taxi_March_2017['tpep_pickup_datetime']).dt.date
Taxi_March_2017['Time'] = pd.to_datetime(Taxi_March_2017['tpep_pickup_datetime']).dt.time
Taxi_March_2017 = Taxi_March_2017[pd.to_datetime(Taxi_March_2017['Date']).dt.month == 3]
Taxi_March_2017 = Taxi_March_2017[pd.to_datetime(Taxi_March_2017['Date']).dt.year == 2017]

Taxi_April_2017 = pd.read_parquet(Path_April_2017)
Taxi_April_2017['Date'] = pd.to_datetime(Taxi_April_2017['tpep_pickup_datetime']).dt.date
Taxi_April_2017['Time'] = pd.to_datetime(Taxi_April_2017['tpep_pickup_datetime']).dt.time
Taxi_April_2017 = Taxi_April_2017[pd.to_datetime(Taxi_April_2017['Date']).dt.month == 4]
Taxi_April_2017 = Taxi_April_2017[pd.to_datetime(Taxi_April_2017['Date']).dt.year == 2017]

Taxi_May_2017 = pd.read_parquet(Path_May_2017)
Taxi_May_2017['Date'] = pd.to_datetime(Taxi_May_2017['tpep_pickup_datetime']).dt.date
Taxi_May_2017['Time'] = pd.to_datetime(Taxi_May_2017['tpep_pickup_datetime']).dt.time
Taxi_May_2017 = Taxi_May_2017[pd.to_datetime(Taxi_May_2017['Date']).dt.month == 5]
Taxi_May_2017 = Taxi_May_2017[pd.to_datetime(Taxi_May_2017['Date']).dt.year == 2017]

Taxi_March_2018 = pd.read_parquet(Path_March_2018)
Taxi_March_2018['Date'] = pd.to_datetime(Taxi_March_2018['tpep_pickup_datetime']).dt.date
Taxi_March_2018['Time'] = pd.to_datetime(Taxi_March_2018['tpep_pickup_datetime']).dt.time
Taxi_March_2018 = Taxi_March_2018[pd.to_datetime(Taxi_March_2018['Date']).dt.month == 3]
Taxi_March_2018 = Taxi_March_2018[pd.to_datetime(Taxi_March_2018['Date']).dt.year == 2018]

Taxi_April_2018 = pd.read_parquet(Path_April_2018)
Taxi_April_2018['Date'] = pd.to_datetime(Taxi_April_2018['tpep_pickup_datetime']).dt.date
Taxi_April_2018['Time'] = pd.to_datetime(Taxi_April_2018['tpep_pickup_datetime']).dt.time
Taxi_April_2018 = Taxi_April_2018[pd.to_datetime(Taxi_April_2018['Date']).dt.month == 4]
Taxi_April_2018 = Taxi_April_2018[pd.to_datetime(Taxi_April_2018['Date']).dt.year == 2018]

Taxi_May_2018 = pd.read_parquet(Path_May_2018)
Taxi_May_2018['Date'] = pd.to_datetime(Taxi_May_2018['tpep_pickup_datetime']).dt.date
Taxi_May_2018['Time'] = pd.to_datetime(Taxi_May_2018['tpep_pickup_datetime']).dt.time
Taxi_May_2018 = Taxi_May_2018[pd.to_datetime(Taxi_May_2018['Date']).dt.month == 5]
Taxi_May_2018 = Taxi_May_2018[pd.to_datetime(Taxi_May_2018['Date']).dt.year == 2018]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-a50dd4e56566> in <module>
#      89
#      90 #Combine dataframes
# ---> 91 Taxi = pd.concat(Taxi_March_2015, Taxi_April_2015, Taxi_May_2015, Taxi_March_2016, Taxi_April_2016, Taxi_May_2016, Taxi_March_2017, Taxi_April_2017, Taxi_May_2017, Taxi_March_2018, Taxi_April_2018, Taxi_May_2018)
#
# TypeError: concat() takes from 1 to 10 positional arguments but 12 were given

# %%
Taxi = pd.concat([Taxi_March_2015, Taxi_April_2015, Taxi_May_2015, Taxi_March_2016, Taxi_April_2016, Taxi_May_2016, Taxi_March_2017, Taxi_April_2017, Taxi_May_2017, Taxi_March_2018, Taxi_April_2018, Taxi_May_2018], axis=0)
Taxi.shape
# Out:
# (133933110, 21)

# %%
Date_Counts = Taxi['Date'].value_counts().sort_index(ascending = True)

# %%
Date_Counts
# Out:
# 2015-03-01    385075
# 2015-03-02    388260
# 2015-03-03    397382
# 2015-03-04    435473
# 2015-03-05    366224
#                ...
# 2018-05-27    203509
# 2018-05-28    187579
# 2018-05-29    275476
# 2018-05-30    301181
# 2018-05-31    315516
# Name: Date, Length: 368, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(Date_Counts)

# %%
#Date_Counts[0:91]= Date_Counts[0:91]/max(Date_Counts[0:91])
#Date_Counts[92:183]= Date_Counts[92:183]/max(Date_Counts[92:183])
#Date_Counts[184:275]= Date_Counts[184:275]/max(Date_Counts[184:275])
#Date_Counts[276:367]= Date_Counts[276:367]/max(Date_Counts[276:367])

# %%
Date_Counts[0:92] = Date_Counts[0:92]/max(Date_Counts[0:92])
Date_Counts[92:184] = Date_Counts[92:184]/max(Date_Counts[92:184])
Date_Counts[184:276] = Date_Counts[184:276]/max(Date_Counts[184:276])
Date_Counts[276:368] = Date_Counts[276:368]/max(Date_Counts[276:368])
Date_Counts
# Out:
# 2015-03-01    0.754793
# 2015-03-02    0.761036
# 2015-03-03    0.778916
# 2015-03-04    0.853579
# 2015-03-05    0.717843
#                 ...
# 2018-05-27    0.581662
# 2018-05-28    0.536131
# 2018-05-29    0.787355
# 2018-05-30    0.860825
# 2018-05-31    0.901796
# Name: Date, Length: 368, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(Date_Counts)

# %%
df = pd.DataFrame(Date_Counts)
df
# Out:
#                 Date
# 2015-03-01  0.754793
# 2015-03-02  0.761036
# 2015-03-03  0.778916
# 2015-03-04  0.853579
# 2015-03-05  0.717843
# ...              ...
# 2018-05-27  0.581662
# 2018-05-28  0.536131
# 2018-05-29  0.787355
# 2018-05-30  0.860825
# 2018-05-31  0.901796
#
# [368 rows x 1 columns]

# %%
Taxi_Drives = []
for i in range (Date_Counts.size):
    Taxi_Drives.append(Date_Counts[i])
Taxi_Drives = np.array(Taxi_Drives)
Taxi_Drives.size
Weather['Taxi Drives'] = Taxi_Drives.tolist()

# %%
result = pd.concat([Weather, df.loc[Date]], axis=1, ignore_index = True)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-186-15ad49e122d8> in <module>
# ----> 1 result = pd.concat([Weather, df.loc[Date]], axis=1, ignore_index = True)
#       2 result
#
# NameError: name 'Date' is not defined

# %%
Weather
# Out:
#               name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0    New York City  2015-03-01     -1.2     -4.5  -2.9          -2.2
# 1    New York City  2015-03-02      3.4     -2.1   0.5          -0.5
# 2    New York City  2015-03-03      2.0     -5.0  -1.8          -1.5
# 3    New York City  2015-03-04      7.2      2.0   4.5           5.8
# 4    New York City  2015-03-05      4.6     -6.4  -2.6           1.7
# ..             ...         ...      ...      ...   ...           ...
# 363  New York City  2018-05-27     26.7     13.9  18.2          26.7
# 364  New York City  2018-05-28     20.6     13.4  16.1          20.6
# 365  New York City  2018-05-29     30.8     17.0  23.7          30.9
# 366  New York City  2018-05-30     23.8     16.1  19.9          23.8
# 367  New York City  2018-05-31     20.0     17.2  18.5          20.0
#
#      feelslikemin  feelslike   dew  humidity  ...  uvindex  severerisk  \
# ...

# %%
Weather.to_csv('Weather_TaxiDrives.csv')
